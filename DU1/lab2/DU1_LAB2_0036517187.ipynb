# %%
import json
import os

from matplotlib import pyplot as plt
import torch

# %%
# !python3 setup_cython.py build_ext --inplace
# Out:
# Compiling im2col_cython.pyx because it changed.
# [1/1] Cythonizing im2col_cython.pyx
# /usr/local/lib/python3.9/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/im2col_cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'im2col_cython' extension
# creating build
# creating build/temp.linux-x86_64-3.9
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.9/dist-packages/numpy/core/include -I/usr/include/python3.9 -c im2col_cython.c -o build/temp.linux-x86_64-3.9/im2col_cython.o
# ...

# %%
# !python3 check_grads.py
# Out:
# Convolution
# Check grad wrt input
# Relative error =  3.23498529262909e-09
# Error norm =  2.446613559727109e-10
# Check grad wrt params
# Check weights:
# Relative error =  1.1591307769056652e-10
# Error norm =  2.2158568767491455e-10
# Check biases:
# Relative error =  5.123358456214563e-12
# Error norm =  9.304381280152754e-11
#
# MaxPooling
# Check grad wrt input
# Relative error =  3.2756458073264858e-12
# Error norm =  9.227612942429045e-11
#
# ReLU
# Check grad wrt input
# Relative error =  3.2756238354620507e-12
# Error norm =  6.098293513873449e-11
#
# FC
# Check grad wrt input
# Relative error =  2.3805539996359982e-08
# Error norm =  7.171441694384837e-10
# Check grad wrt params
# Check weights:
# Relative error =  2.2851434098221648e-09
# Error norm =  7.244823234882981e-10
# Check biases:
# Relative error =  1.846578456474158e-11
# Error norm =  1.0463678143508723e-10
#
# SoftmaxCrossEntropyWithLogits
# Relative error =  3.9701249947092284e-07
# ...

# %% [markdown]
# Uvijek se koristi jednostruka (float32) preciznost, pa L2Regularizer može premašiti grešku od 10^-5.

# %%
# !python3 train.py
# Out:
# /content/train.py:26: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_x = ds_train.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# /content/train.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_x = ds_test.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# ...

# %%
# !python3 train_l2reg.py #2 epohe umjesto 8 da se krace trenira, reg = 0.001
# Out:
# /content/train_l2reg.py:27: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_x = ds_train.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# /content/train_l2reg.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_x = ds_test.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# ...

# %%
# !python3 train_l2reg.py #2 epohe umjesto 8 da se krace trenira, reg = 0.01
# Out:
# /content/train_l2reg.py:27: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_x = ds_train.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# /content/train_l2reg.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_x = ds_test.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# ...

# %%
# !python3 train_l2reg.py #2 epohe umjesto 8 da se krace trenira, reg = 0.1
# Out:
# /content/train_l2reg.py:27: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_x = ds_train.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# /content/train_l2reg.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_x = ds_test.data.reshape([-1, 1, 28, 28]).numpy().astype(np.float) / 255
# ...

# %% [markdown]
# Najveći accuracy za najamanji regularizacijski faktor. Najinterpretabilnije slike za 10^-2.

# %%
# %matplotlib inline

# !python3 zad3.py
# Out:
# Using device cpu
# [0,     0] loss: 2.615
# [0,  5000] loss: 1.269
# [0, 10000] loss: 0.432
# [0, 15000] loss: 0.323
# [0, 20000] loss: 0.267
# [0, 25000] loss: 0.237
# [0, 30000] loss: 0.191
# [0, 35000] loss: 0.184
# [0, 40000] loss: 0.173
# [0, 45000] loss: 0.161
# [0, 50000] loss: 0.161
# [0, 55000] loss: 0.140
# [1,     0] loss: 0.124
# [1,  5000] loss: 0.116
# [1, 10000] loss: 0.117
# [1, 15000] loss: 0.111
# [1, 20000] loss: 0.107
# [1, 25000] loss: 0.106
# [1, 30000] loss: 0.104
# [1, 35000] loss: 0.095
# [1, 40000] loss: 0.101
# [1, 45000] loss: 0.100
# [1, 50000] loss: 0.096
# [1, 55000] loss: 0.086
# Finished Training
# Accuracy on 10000 test images: 97.0 %

# %%
# !python3 zad3.py
# Out:
# Using device cpu
# [0,     0] loss: 2.756
# [0,  5000] loss: 1.257
# [0, 10000] loss: 0.425
# [0, 15000] loss: 0.306
# [0, 20000] loss: 0.255
# [0, 25000] loss: 0.228
# [0, 30000] loss: 0.193
# [0, 35000] loss: 0.179
# [0, 40000] loss: 0.171
# [0, 45000] loss: 0.152
# [0, 50000] loss: 0.159
# [0, 55000] loss: 0.137
# [1,     0] loss: 0.119
# [1,  5000] loss: 0.128
# [1, 10000] loss: 0.118
# [1, 15000] loss: 0.109
# [1, 20000] loss: 0.108
# [1, 25000] loss: 0.111
# [1, 30000] loss: 0.102
# [1, 35000] loss: 0.108
# [1, 40000] loss: 0.103
# [1, 45000] loss: 0.103
# [1, 50000] loss: 0.102
# [1, 55000] loss: 0.119
# Finished Training
# Accuracy on 10000 test images: 97.0 %

# %%
# !python3 zad3.py
# Out:
# Using device cpu
# [0,     0] loss: 2.429
# [0,  5000] loss: 1.494
# [0, 10000] loss: 0.582
# [0, 15000] loss: 0.435
# [0, 20000] loss: 0.402
# [0, 25000] loss: 0.362
# [0, 30000] loss: 0.345
# [0, 35000] loss: 0.336
# [0, 40000] loss: 0.323
# [0, 45000] loss: 0.321
# [0, 50000] loss: 0.313
# [0, 55000] loss: 0.295
# [1,     0] loss: 0.265
# [1,  5000] loss: 0.294
# [1, 10000] loss: 0.300
# [1, 15000] loss: 0.284
# [1, 20000] loss: 0.288
# [1, 25000] loss: 0.290
# [1, 30000] loss: 0.281
# [1, 35000] loss: 0.292
# [1, 40000] loss: 0.281
# [1, 45000] loss: 0.276
# [1, 50000] loss: 0.276
# [1, 55000] loss: 0.298
# Finished Training
# Accuracy on 10000 test images: 94.0 %

# %%
# !python3 zad4.py
# Out:
# Using device cpu
# Files already downloaded and verified
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch: 0, step: 100, batch_loss: 2.302434
# epoch: 0, step: 200, batch_loss: 2.297562
# epoch: 0, step: 300, batch_loss: 2.296238
# epoch: 0, step: 400, batch_loss: 2.292344
# epoch: 0, step: 500, batch_loss: 2.287473
# epoch: 0, step: 600, batch_loss: 2.273935
# epoch: 0, step: 700, batch_loss: 2.257569
# epoch: 0, step: 800, batch_loss: 2.211765
# epoch: 0, step: 900, batch_loss: 2.146026
# epoch: 0, step: 1000, batch_loss: 2.075728
# ...

# %%
# !zip -r /content/z4.zip /content/out_z4
# Out:
#   adding: content/out_z4/ (stored 0%)
#   adding: content/out_z4/epoch_01_step_000200.png (stored 0%)
#   adding: content/out_z4/epoch_07_step_002000.png (stored 0%)
#   adding: content/out_z4/epoch_05_step_001200.png (stored 0%)
#   adding: content/out_z4/epoch_01_step_001200.png (stored 0%)
#   adding: content/out_z4/epoch_07_step_000200.png (stored 0%)
#   adding: content/out_z4/epoch_04_step_001200.png (stored 0%)
#   adding: content/out_z4/epoch_00_step_002800.png (stored 0%)
#   adding: content/out_z4/epoch_03_step_001000.png (stored 0%)
#   adding: content/out_z4/epoch_03_step_001800.png (stored 0%)
#   adding: content/out_z4/epoch_01_step_002800.png (stored 0%)
#   adding: content/out_z4/epoch_06_step_000800.png (stored 0%)
#   adding: content/out_z4/epoch_06_step_000600.png (stored 0%)
#   adding: content/out_z4/epoch_03_step_000800.png (stored 0%)
#   adding: content/out_z4/epoch_07_step_002800.png (stored 0%)
#   adding: content/out_z4/epoch_03_step_000000.png (stored 0%)
# ...
